# %%
import numpy as np
import pandas as pd
pd.set_option("Display.max_column", None)
pd.set_option("Display.max_rows", None)

# %%
ctg = pd.read_csv(r"C:\Users\rhuta\Downloads\CTG.csv")
ctg
# Out:
#        LB     AC     FM  NSP
# 0     120  0.000  0.000    2
# 1     132  0.006  0.000    1
# 2     133  0.003  0.000    1
# 3     134  0.003  0.000    1
# 4     132  0.007  0.000    1
# 5     134  0.001  0.000    3
# 6     134  0.001  0.000    3
# 7     122  0.000  0.000    3
# 8     122  0.000  0.000    3
# 9     122  0.000  0.000    3
# 10    151  0.000  0.000    2
# 11    150  0.000  0.000    2
# 12    131  0.005  0.072    1
# 13    131  0.009  0.222    1
# 14    130  0.006  0.408    1
# 15    130  0.006  0.380    1
# 16    130  0.006  0.441    1
# 17    131  0.002  0.383    2
# 18    130  0.003  0.451    1
# 19    130  0.005  0.469    1
# 20    129  0.000  0.340    3
# 21    128  0.005  0.425    1
# 22    128  0.000  0.334    3
# 23    128  0.000  0.000    3
# 24    128  0.000  0.000    3
# 25    124  0.000  0.000    3
# 26    124  0.000  0.000    3
# 27    124  0.000  0.000    3
# 28    132  0.000  0.135    2
# 29    132  0.000  0.099    1
# 30    132  0.000  0.108    1
# ...

# %%
ctg.shape
# Out:
# (2126, 4)

# %%
ctg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LB      2126 non-null   int64
#  1   AC      2126 non-null   float64
#  2   FM      2126 non-null   float64
#  3   NSP     2126 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 66.6 KB

# %%
#Sampling

# %%
from sklearn.model_selection import train_test_split

# %%
ctg_train,ctg_test = train_test_split(ctg, test_size = 0.2)

# %%
#Check for oversampling
df1=ctg_train[ctg_train.NSP==2]
df2=ctg_train[ctg_train.NSP==3]

# %%
df1.shape
# Out:
# (234, 4)

# %%
ctg_train = pd.concat([ctg_train, df1, df1, df2,df2, df2, df2])

# %%
ctg_train.NSP.value_counts()
# Out:
# 1    1316
# 3     750
# 2     702
# Name: NSP, dtype: int64

# %%
ctg_train_x = ctg_train.iloc[:, 0:1]
ctg_train_y = ctg_train.iloc[:,-1]

# %%
ctg_test_x = ctg_train.iloc[:, 0:1]
ctg_test_y = ctg_train.iloc[:,-1]

# %%
#Building model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier(criterion = 'gini')
#dtree = DecisionTreeClassfier(criterion = 'entropy', max_depth = 4.nim_samples_split=50)

# %%
dtree.fit(ctg_train_x, ctg_train_y)
# Out:
# DecisionTreeClassifier()

# %%
dec_pred = dtree.predict(ctg_test_x)
dec_pred
# Out:
# array([1, 1, 1, ..., 3, 1, 3], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix

# %%
dtree_cm = confusion_matrix(ctg_test_y, dec_pred)

# %%
dtree_cm
# Out:
# array([[843, 216, 257],
#        [210, 381, 111],
#        [260,  75, 415]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ctg_test_y, dec_pred)*100
# Out:
# 59.21242774566474
